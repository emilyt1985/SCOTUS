# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# Set file path
csv_file = "SCDB_2018_02_justiceCentered_Citation.csv"

# %%
# import csv
scotus = pd.read_csv(csv_file, encoding = "latin1")
scotus.head()
# Out:
#      caseId     docketId    caseIssuesId                voteId dateDecision  \
# 0  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-01   11/18/1946
# 1  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-02   11/18/1946
# 2  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-03   11/18/1946
# 3  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-04   11/18/1946
# 4  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-05   11/18/1946
#
#    decisionType      usCite      sctCite      ledCite             lexisCite  \
# 0             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 1             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 2             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 3             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 4             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
#
# ...

# %%
# Set columns
vote_df = scotus[["justice", "justiceName", "majVotes", "direction", "minVotes", "decisionDirection", "majority", "caseId", "term", "partyWinning", "precedentAlteration", "vote", "issueArea"]]

vote_df.head()
# Out:
#    justice   justiceName  majVotes  direction  minVotes  decisionDirection  \
# 0       86      HHBurton         8        1.0         1                2.0
# 1       84     RHJackson         8        2.0         1                2.0
# 2       81     WODouglas         8        2.0         1                2.0
# 3       80  FFrankfurter         8        2.0         1                2.0
# 4       79        SFReed         8        2.0         1                2.0
#
#    majority    caseId  term  partyWinning  precedentAlteration  vote  \
# 0       1.0  1946-001  1946           1.0                  1.0   2.0
# 1       2.0  1946-001  1946           1.0                  1.0   1.0
# 2       2.0  1946-001  1946           1.0                  1.0   1.0
# 3       2.0  1946-001  1946           1.0                  1.0   4.0
# 4       2.0  1946-001  1946           1.0                  1.0   1.0
#
#    issueArea
# 0        8.0
# 1        8.0
# 2        8.0
# 3        8.0
# 4        8.0

# %%
# Drop some NAs
votes = vote_df.dropna(axis=0, subset=['issueArea'])

# %%
# Set others to zero
vote_counts = votes.fillna(0)

# %%
# Set floats to integers
vote = vote_counts.astype({"partyWinning": int, "direction": int, "precedentAlteration": int, "majority": int, "decisionDirection": int, "vote": int, "issueArea": int})

# %%
# Export to csv
vote.to_csv("full_votes.csv")
