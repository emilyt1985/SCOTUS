# %%
import pandas as pd
import numpy as np

# %%
csv_file = "SCDB_2018_02_justiceCentered_Citation.csv"
scotus = pd.read_csv(csv_file, encoding = "latin1")
scotus.head()
# Out:
#      caseId     docketId    caseIssuesId                voteId dateDecision  \
# 0  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-01   11/18/1946
# 1  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-02   11/18/1946
# 2  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-03   11/18/1946
# 3  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-04   11/18/1946
# 4  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-05   11/18/1946
#
#    decisionType      usCite      sctCite      ledCite             lexisCite  \
# 0             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 1             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 2             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 3             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 4             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
#
# ...

# %%
current_df = scotus[["lexisCite", "term", "justice", "justiceName", "direction", "majority", "majVotes", "minVotes",
                      "issueArea", "decisionDirection", "caseOriginState", "precedentAlteration", "lawType"]]

current_df.head()
# Out:
#               lexisCite  term  justice   justiceName  direction  majority  \
# 0  1946 U.S. LEXIS 1724  1946       86      HHBurton        1.0       1.0
# 1  1946 U.S. LEXIS 1724  1946       84     RHJackson        2.0       2.0
# 2  1946 U.S. LEXIS 1724  1946       81     WODouglas        2.0       2.0
# 3  1946 U.S. LEXIS 1724  1946       80  FFrankfurter        2.0       2.0
# 4  1946 U.S. LEXIS 1724  1946       79        SFReed        2.0       2.0
#
#    majVotes  minVotes  issueArea  decisionDirection  caseOriginState  \
# 0         8         1        8.0                2.0              6.0
# 1         8         1        8.0                2.0              6.0
# 2         8         1        8.0                2.0              6.0
# 3         8         1        8.0                2.0              6.0
# 4         8         1        8.0                2.0              6.0
#
#    precedentAlteration  lawType
# 0                  1.0      6.0
# 1                  1.0      6.0
# ...

# %%
noNA = current_df.dropna(axis=0)

# %%
current_df = noNA.fillna(0)
current_df.dtypes
# Out:
# lexisCite               object
# term                     int64
# justice                  int64
# justiceName             object
# direction              float64
# majority               float64
# majVotes                 int64
# minVotes                 int64
# issueArea              float64
# decisionDirection      float64
# caseOriginState        float64
# precedentAlteration    float64
# lawType                float64
# dtype: object

# %%
current_df = current_df.astype({"term": int, "caseOriginState": int, "precedentAlteration": int, 
                                "issueArea": int, "decisionDirection": int, "lawType": int, "majVotes": int,
                               "minVotes": int, "majority": int, "justice": int, "direction": int})
current_df.head()
# Out:
#               lexisCite  term  justice   justiceName  direction  majority  \
# 0  1946 U.S. LEXIS 1724  1946       86      HHBurton          1         1
# 1  1946 U.S. LEXIS 1724  1946       84     RHJackson          2         2
# 2  1946 U.S. LEXIS 1724  1946       81     WODouglas          2         2
# 3  1946 U.S. LEXIS 1724  1946       80  FFrankfurter          2         2
# 4  1946 U.S. LEXIS 1724  1946       79        SFReed          2         2
#
#    majVotes  minVotes  issueArea  decisionDirection  caseOriginState  \
# 0         8         1          8                  2                6
# 1         8         1          8                  2                6
# 2         8         1          8                  2                6
# 3         8         1          8                  2                6
# 4         8         1          8                  2                6
#
#    precedentAlteration  lawType
# 0                    1        6
# 1                    1        6
# ...

# %%
current_scotus = current_df[current_df["justice"] > 107]
current_scotus.head()
# Out:
#                   lexisCite  term  justice justiceName  direction  majority  \
# 58811  1991 U.S. LEXIS 7062  1991      108     CThomas          1         2
# 58946   1992 U.S. LEXIS 378  1991      108     CThomas          1         2
# 59090  1992 U.S. LEXIS 1536  1991      108     CThomas          1         1
# 59099  1992 U.S. LEXIS 1535  1991      108     CThomas          2         2
# 59243  1992 U.S. LEXIS 2115  1991      108     CThomas          2         2
#
#        majVotes  minVotes  issueArea  decisionDirection  caseOriginState  \
# 58811         9         0          9                  1               12
# 58946         9         0          1                  1               17
# 59090         8         1          3                  2                9
# 59099         9         0          8                  2               27
# 59243         9         0          4                  2                6
#
#        precedentAlteration  lawType
# ...

# %%
current_scotus.to_csv("Current-SCOTUS-Data.csv")
