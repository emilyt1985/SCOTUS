# %%
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("109justice.csv")
df = df.dropna(subset=["vote"])
df.head()
# Out:
#    justice    caseId  term  majVotes  minVotes  decisionDirection  direction  \
# 0      109  1993-001  1993         9         0                  1          1
# 1      109  1993-002  1993         9         0                  1          1
# 2      109  1993-003  1993         9         0                  2          2
# 3      109  1993-004  1993         9         0                  2          2
# 4      109  1993-005  1993         7         2                  1          1
#
#    majority  partyWinning  precedentAlteration  vote  issueArea
# 0         2             0                    0     1          2
# 1         2             0                    0     1          2
# 2         2             0                    0     1          2
# 3         2             1                    0     3          2
# 4         2             0                    0     1          9
